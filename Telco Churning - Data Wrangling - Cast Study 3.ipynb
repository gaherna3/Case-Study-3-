# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Data\CustomerChurn.xlsx')

# %%
#Exploring the Data
df.head()
# Out:
#    LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0     318537  7590-VHVEG             No     Yes         No       1
# 1     152148  5575-GNVDE             No      No         No      34
# 2     326527  3668-QPYBK             No      No         No       2
# 3     845894  7795-CFOCW             No      No         No      45
# 4     503388  9237-HQITU             No      No         No       2
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1           Yes                No              DSL             Yes  ...
# 2           Yes                No              DSL             Yes  ...
# 3            No  No phone service              DSL             Yes  ...
# 4           Yes                No      Fiber optic              No  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# 1               Yes           No           No               No
# 2                No           No           No               No
# 3               Yes          Yes           No               No
# 4                No           No           No               No
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes           Electronic check
# 1        One year                No               Mailed check
# 2  Month-to-month               Yes               Mailed check
# 3        One year                No  Bank transfer (automatic)
# 4  Month-to-month               Yes           Electronic check
#
#   Monthly Charges  Total Charges Churn
# 0           29.85          29.85    No
# 1           56.95         1889.5    No
# 2           53.85         108.15   Yes
# 3           42.30        1840.75    No
# 4           70.70         151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#            LoyaltyID       Tenure  Monthly Charges
# count    7043.000000  7043.000000      7043.000000
# mean   550382.651001    32.371149        64.761692
# std    260776.118690    24.559481        30.090047
# min    100346.000000     0.000000        18.250000
# 25%    323604.500000     9.000000        35.500000
# 50%    548704.000000    29.000000        70.350000
# 75%    776869.000000    55.000000        89.850000
# max    999912.000000    72.000000       118.750000

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info
# Out:
# <bound method DataFrame.info of       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0        318537  7590-VHVEG             No     Yes         No       1
# 1        152148  5575-GNVDE             No      No         No      34
# 2        326527  3668-QPYBK             No      No         No       2
# 3        845894  7795-CFOCW             No      No         No      45
# 4        503388  9237-HQITU             No      No         No       2
# ...         ...         ...            ...     ...        ...     ...
# 7038     810338  6840-RESVB             No     Yes        Yes      24
# 7039     230811  2234-XADUH             No     Yes        Yes      72
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0               No  No phone service              DSL              No  ...
# 1              Yes                No              DSL             Yes  ...
# 2              Yes                No              DSL             Yes  ...
# 3               No  No phone service              DSL             Yes  ...
# 4              Yes                No      Fiber optic              No  ...
# ...            ...               ...              ...             ...  ...
# 7038           Yes               Yes              DSL             Yes  ...
# 7039           Yes               Yes      Fiber optic              No  ...
# 7040            No  No phone service              DSL             Yes  ...
# 7041           Yes               Yes      Fiber optic              No  ...
# 7042           Yes                No      Fiber optic             Yes  ...
#
#      Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                   No           No           No               No
# 1                  Yes           No           No               No
# 2                   No           No           No               No
# 3                  Yes          Yes           No               No
# 4                   No           No           No               No
# ...                ...          ...          ...              ...
# 7038               Yes          Yes          Yes              Yes
# 7039               Yes           No          Yes              Yes
# 7040                No           No           No               No
# 7041                No           No           No               No
# 7042               Yes          Yes          Yes              Yes
#
#             Contract Paperless Billing             Payment Method  \
# 0     Month-to-month               Yes           Electronic check
# 1           One year                No               Mailed check
# 2     Month-to-month               Yes               Mailed check
# 3           One year                No  Bank transfer (automatic)
# 4     Month-to-month               Yes           Electronic check
# ...              ...               ...                        ...
# 7038        One year               Yes               Mailed check
# 7039        One year               Yes    Credit card (automatic)
# 7040  Month-to-month               Yes           Electronic check
# 7041  Month-to-month               Yes               Mailed check
# 7042        Two year               Yes  Bank transfer (automatic)
#
#      Monthly Charges  Total Charges Churn
# 0              29.85          29.85    No
# 1              56.95         1889.5    No
# 2              53.85         108.15   Yes
# 3              42.30        1840.75    No
# 4              70.70         151.65   Yes
# ...              ...            ...   ...
# 7038           84.80         1990.5    No
# 7039          103.20         7362.9    No
# 7040           29.60         346.45    No
# 7041           74.40          306.6   Yes
# 7042          105.65         6844.5    No
#
# [7043 rows x 21 columns]>

# %%
df.dtypes
# Out:
# LoyaltyID              int64
# Customer ID           object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure                 int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn                 object
# dtype: object

# %%
df_dup = df[df.duplicated()]
df_dup
# Out:
# Empty DataFrame
# Columns: [LoyaltyID, Customer ID, Senior Citizen, Partner, Dependents, Tenure, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.nunique()
#Every Customer has a unique customer ID but there are som duplicate Loyalty IDs
# Out:
# LoyaltyID            7021
# Customer ID          7043
# Senior Citizen          2
# Partner                 2
# Dependents              2
# Tenure                 73
# Phone Service           2
# Multiple Lines          3
# Internet Service        3
# Online Security         3
# Online Backup           3
# Device Protection       3
# Tech Support            3
# Streaming TV            3
# Streaming Movies        3
# Contract                3
# Paperless Billing       2
# Payment Method          4
# Monthly Charges      1585
# Total Charges        6531
# Churn                   2
# dtype: int64

# %%
df_dup_loy= df[df.duplicated(['LoyaltyID'], keep=False)]
df_dup_loy.sort_values(by='LoyaltyID', inplace=True)
df_dup_loy
# Out:
# <ipython-input-10-b6f173b0931d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dup_loy.sort_values(by='LoyaltyID', inplace=True)
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 4059     107296  3415-TAILE             No     Yes        Yes       2
# 4683     107296  9360-OMDZZ             No      No         No      24
# 3831     157658  6946-LMSQS            Yes     Yes         No      25
# 2295     157658  2672-DZUOY             No      No         No       1
# 6052     181463  2516-XSJKX             No     Yes        Yes      41
# 4724     181463  5073-RZGBK             No     Yes        Yes      50
# 4147     217416  3836-FZSDJ            Yes     Yes         No      71
# 6346     217416  9661-MHUMO            Yes     Yes        Yes       1
# 1103     223958  7722-CVFXN             No     Yes        Yes      54
# 1898     223958  6689-TCZHQ            Yes      No         No       5
# 6958     372220  3078-ZKNTS             No     Yes        Yes      13
# 5640     372220  5393-RXQSZ             No      No         No       1
# 4835     374243  2360-RDGRO             No     Yes         No      65
# 6312     374243  7055-VKGDA             No      No         No      54
# 812      464187  8098-TDCBU             No     Yes         No      42
# 111      464187  4549-ZDQYY             No      No         No      52
# 2907     464256  0611-DFXKO             No     Yes         No      20
# 6471     464256  0859-YGKFW             No     Yes        Yes      18
# 4289     464631  2228-BZDEE             No      No         No      54
# 5899     464631  9943-VSZUV            Yes      No         No      67
# 255      527640  4111-BNXIF             No     Yes        Yes      67
# 4612     527640  6723-CEGQI             No      No        Yes      65
# 6802     623327  5626-MGTUK             No      No         No      20
# 4911     623327  8565-WUXZU            Yes     Yes         No      72
# 1107     707470  0971-QIFJK             No     Yes         No      69
# 5201     707470  6202-JVYEU             No      No         No       9
# 2430     750578  1821-BUCWY             No      No         No      30
# 1471     750578  9777-WJJPR             No     Yes         No      31
# 2217     750665  0839-JTCUD             No     Yes        Yes      66
# 5416     750665  8961-QDZZJ             No     Yes        Yes      57
# 4871     750739  6848-YLDFR             No     Yes        Yes      58
# 5078     750739  9402-ROUMJ             No     Yes        Yes      67
# 4781     758389  9814-AOUDH             No      No         No      53
# 535      758389  5348-CAGXB             No      No         No      12
# 2625     789225  0880-FVFWF             No      No         No      56
# 4350     789225  1518-OMDIK             No     Yes         No      33
# 2196     820634  6131-IUNXN             No     Yes        Yes      19
# 3889     820634  2592-HODOV             No      No         No      13
# 7025     842064  2823-LKABH             No      No         No      18
# 1570     842064  3070-FNFZQ             No     Yes        Yes      23
# 649      962480  3509-GWQGF            Yes      No         No      24
# 5207     962480  9381-NDKME            Yes     Yes         No      24
# 4839     980245  3070-DVEYC            Yes      No         No       7
# 80       980245  5919-TMRGD             No      No        Yes       1
#
#      Phone Service    Multiple Lines Internet Service      Online Security  \
# 4059           Yes                No              DSL                   No
# 4683           Yes               Yes      Fiber optic                   No
# 3831           Yes               Yes      Fiber optic                  Yes
# 2295            No  No phone service              DSL                   No
# 6052           Yes                No              DSL                  Yes
# 4724           Yes               Yes              DSL                  Yes
# 4147           Yes               Yes               No  No internet service
# 6346           Yes                No              DSL                   No
# 1103           Yes               Yes      Fiber optic                   No
# 1898           Yes                No      Fiber optic                   No
# 6958           Yes                No               No  No internet service
# 5640           Yes                No      Fiber optic                   No
# 4835           Yes               Yes      Fiber optic                  Yes
# 6312           Yes                No      Fiber optic                  Yes
# 812            Yes               Yes               No  No internet service
# 111            Yes                No              DSL                  Yes
# 2907           Yes                No      Fiber optic                   No
# 6471           Yes                No               No  No internet service
# 4289           Yes                No               No  No internet service
# 5899           Yes               Yes      Fiber optic                   No
# 255             No  No phone service              DSL                   No
# 4612            No  No phone service              DSL                   No
# 6802           Yes               Yes      Fiber optic                  Yes
# 4911           Yes                No      Fiber optic                  Yes
# 1107           Yes               Yes               No  No internet service
# 5201           Yes                No               No  No internet service
# 2430           Yes                No              DSL                  Yes
# 1471           Yes               Yes      Fiber optic                   No
# 2217           Yes               Yes              DSL                  Yes
# 5416           Yes                No      Fiber optic                   No
# 4871           Yes                No              DSL                   No
# 5078           Yes               Yes      Fiber optic                  Yes
# 4781           Yes                No               No  No internet service
# 535            Yes               Yes      Fiber optic                   No
# 2625           Yes               Yes      Fiber optic                  Yes
# 4350           Yes                No              DSL                   No
# 2196           Yes                No               No  No internet service
# 3889           Yes                No               No  No internet service
# 7025           Yes               Yes      Fiber optic                   No
# 1570           Yes                No               No  No internet service
# 649            Yes                No      Fiber optic                   No
# 5207            No  No phone service              DSL                   No
# 4839           Yes               Yes      Fiber optic                   No
# 80             Yes                No      Fiber optic                   No
#
#       ...    Device Protection         Tech Support         Streaming TV  \
# 4059  ...                   No                   No                  Yes
# 4683  ...                   No                   No                  Yes
# 3831  ...                   No                   No                   No
# 2295  ...                   No                   No                   No
# 6052  ...                   No                  Yes                  Yes
# 4724  ...                  Yes                  Yes                   No
# 4147  ...  No internet service  No internet service  No internet service
# 6346  ...                   No                  Yes                   No
# 1103  ...                   No                  Yes                  Yes
# 1898  ...                   No                   No                   No
# 6958  ...  No internet service  No internet service  No internet service
# 5640  ...                   No                   No                   No
# 4835  ...                  Yes                   No                  Yes
# 6312  ...                   No                  Yes                  Yes
# 812   ...  No internet service  No internet service  No internet service
# 111   ...                  Yes                  Yes                   No
# 5640           Electronic check           79.60           79.6   Yes
# 4835           Electronic check          104.25        6812.95    No
# 6312    Credit card (automatic)          105.40         5643.4   Yes
# 812            Electronic check           25.25         1108.2    No
# 111     Credit card (automatic)           57.95        3042.25    No
# 2907               Mailed check           89.00        1820.45   Yes
# 6471  Bank transfer (automatic)           20.05          345.9    No
# 4289               Mailed check           20.10        1079.45    No
# 5899               Mailed check           75.70        5060.85    No
# 255            Electronic check           59.55         4103.9    No
# 4612               Mailed check           45.25        2933.95    No
# 6802  Bank transfer (automatic)           89.10        1879.25    No
# 4911    Credit card (automatic)           84.80        6141.65    No
# 1107  Bank transfer (automatic)           24.25         1641.8    No
# 5201           Electronic check           19.90          164.6    No
# 2430               Mailed check           55.65        1653.85    No
# 1471    Credit card (automatic)           88.65         2683.2    No
# 2217    Credit card (automatic)           89.90        5958.85    No
# 5416           Electronic check           95.00         5535.8    No
# 4871    Credit card (automatic)           75.20         4300.8    No
# 5078  Bank transfer (automatic)          100.25           6689    No
# 4781    Credit card (automatic)           19.50         1050.5    No
# 535            Electronic check           89.55        1021.75    No
# 2625           Electronic check           86.40         4922.4    No
# 4350    Credit card (automatic)           44.55         1462.6    No
# 2196               Mailed check           20.20          382.2    No
# 3889    Credit card (automatic)           19.30         259.65    No
# 7025  Bank transfer (automatic)           95.05         1679.4    No
# 1570  Bank transfer (automatic)           20.40         478.75    No
# 649     Credit card (automatic)           70.00         1732.6    No
# 5207    Credit card (automatic)           40.65          933.3   Yes
# 4839               Mailed check           73.75         545.15   Yes
# 80             Electronic check           79.35          79.35   Yes
#
# [44 rows x 21 columns]

# %%
df['Tenure'].nunique()
# Out:
# 73

# %%
df.isnull().sum()
# Out:
# LoyaltyID            0
# Customer ID          0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure               0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn                0
# dtype: int64

# %%
df['Payment Method'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df['Multiple Lines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
df['Internet Service'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df['Online Security'].unique()
#Check to see if this corresponds with Internet Service
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df.loc[(df['Internet Service'] == 'No') & (df['Online Security'] != 'No internet service')]
# Out:
# Empty DataFrame
# Columns: [LoyaltyID, Customer ID, Senior Citizen, Partner, Dependents, Tenure, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Online Backup'].unique()
#Check to see if this corresponds with Internet Service
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df.loc[(df['Internet Service'] == 'No') & (df['Online Backup'] != 'No internet service')]
# Out:
# Empty DataFrame
# Columns: [LoyaltyID, Customer ID, Senior Citizen, Partner, Dependents, Tenure, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Device Protection'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df.loc[(df['Internet Service'] == 'No') & (df['Device Protection'] != 'No internet service')]
# Out:
# Empty DataFrame
# Columns: [LoyaltyID, Customer ID, Senior Citizen, Partner, Dependents, Tenure, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Tech Support'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df.loc[(df['Internet Service'] == 'No') & (df['Tech Support'] != 'No internet service')]
# Out:
# Empty DataFrame
# Columns: [LoyaltyID, Customer ID, Senior Citizen, Partner, Dependents, Tenure, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Streaming TV'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df.loc[(df['Internet Service'] == 'No') & (df['Streaming TV'] != 'No internet service')]
# Out:
# Empty DataFrame
# Columns: [LoyaltyID, Customer ID, Senior Citizen, Partner, Dependents, Tenure, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Streaming Movies'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df.loc[(df['Internet Service'] == 'No') & (df['Streaming Movies'] != 'No internet service')]
# Out:
# Empty DataFrame
# Columns: [LoyaltyID, Customer ID, Senior Citizen, Partner, Dependents, Tenure, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)
